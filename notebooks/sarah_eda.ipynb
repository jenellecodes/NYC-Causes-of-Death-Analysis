# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # General Exploration

# %%
df = pd.read_csv("../data/processed/clean_data.csv")

df.head(20)
# Out:
#        Unnamed: 0  incident_key               occur_date occur_time  \
# 0               0     209281500  2020-02-08T00:00:00.000   12:13:00
# 1               1     209281497  2020-02-08T00:00:00.000   02:20:00
# 2               2     209281498  2020-02-07T00:00:00.000   22:50:00
# 3               3     209099251  2020-02-05T00:00:00.000   04:02:00
# 4               4     209098666  2020-02-05T00:00:00.000   23:13:00
# ...           ...           ...                      ...        ...
# 28995         995     240338259  2022-02-09T00:00:00.000   00:45:00
# 28996         996     240379307  2022-02-09T00:00:00.000   13:33:00
# 28997         997     240321242  2022-02-08T00:00:00.000   00:30:00
# 28998         998     240321668  2022-02-08T00:00:00.000   20:02:00
# 28999         999     240321668  2022-02-08T00:00:00.000   20:02:00
#
#             boro  precinct  jurisdiction_code  statistical_murder_flag  \
# 0         QUEENS       115                0.0                     True
# 1       BROOKLYN        76                0.0                     True
# 2       BROOKLYN        75                0.0                    False
# 3         QUEENS       101                0.0                    False
# 4      MANHATTAN        34                0.0                    False
# ...          ...       ...                ...                      ...
# 28995   BROOKLYN        75                0.0                     True
# 28996   BROOKLYN        90                2.0                    False
# 28997      BRONX        48                0.0                    False
# 28998   BROOKLYN        69                0.0                    False
# 28999   BROOKLYN        69                0.0                    False
#
#       perp_age_group perp_sex  ...               :created_at  \
# 0              25-44        M  ...  2024-04-23T13:36:19.239Z
# 1              25-44        M  ...  2024-04-23T13:36:19.239Z
# 2              25-44        M  ...  2024-04-23T13:36:19.239Z
# 3                NaN      NaN  ...  2024-04-23T13:36:19.239Z
# 4              18-24        M  ...  2024-04-23T13:36:19.239Z
# ...              ...      ...  ...                       ...
# 28995         (null)   (null)  ...  2024-04-23T13:36:19.239Z
# 28996         (null)   (null)  ...  2024-04-23T13:36:19.239Z
# 28997         (null)   (null)  ...  2024-04-23T13:36:19.239Z
# 28998          25-44        M  ...  2024-04-23T13:36:19.239Z
# 28999          18-24        M  ...  2024-04-23T13:36:19.239Z
#
#                     :updated_at :@computed_region_yeji_bk3q  \
# 0      2024-04-23T13:36:30.560Z                         3.0
# 1      2024-04-23T13:36:30.560Z                         2.0
# 2      2024-04-23T13:36:30.560Z                         2.0
# 3      2024-04-23T13:36:30.560Z                         3.0
# 4      2024-04-23T13:36:30.560Z                         4.0
# ...                         ...                         ...
# 28995  2024-04-23T13:36:30.560Z                         2.0
# 28996  2024-04-23T13:36:30.560Z                         2.0
# 28997  2024-04-23T13:36:30.560Z                         5.0
# 28998  2024-04-23T13:36:30.560Z                         2.0
# 28999  2024-04-23T13:36:30.560Z                         2.0
#
#       :@computed_region_92fq_4b7q :@computed_region_sbqj_enih  \
# 0                            21.0                        73.0
# 1                             7.0                        48.0
# 2                            37.0                        47.0
# 3                            47.0                        59.0
# 4                            39.0                        22.0
# ...                           ...                         ...
# 28995                        37.0                        47.0
# 28996                        30.0                        56.0
# 28997                        43.0                        31.0
# 28998                         8.0                        42.0
# 28999                         8.0                        42.0
#
#       :@computed_region_efsh_h5xi  :@computed_region_f5dn_yrer  \
# 0                         14510.0                         65.0
# 1                         13514.0                         14.0
# 2                         17214.0                         45.0
# 3                         20529.0                         51.0
# 4                         13098.0                         47.0
# ...                           ...                          ...
# 28995                     17215.0                         45.0
# 28996                     17213.0                         36.0
# 28997                     11269.0                         35.0
# 28998                     13827.0                          5.0
# 28999                     13827.0                          5.0
#
#                    location_desc loc_of_occur_desc loc_classfctn_desc
# 0                            NaN               NaN                NaN
# 1                            NaN               NaN                NaN
# 2                            NaN               NaN                NaN
# 3        MULTI DWELL - APT BUILD               NaN                NaN
# 4        MULTI DWELL - APT BUILD               NaN                NaN
# ...                          ...               ...                ...
# 28995                  PVT HOUSE           OUTSIDE             STREET
# 28996  MULTI DWELL - PUBLIC HOUS            INSIDE            HOUSING
# 28997                     (null)           OUTSIDE             STREET
# 28998                     (null)           OUTSIDE             STREET
# 28999                     (null)           OUTSIDE             STREET
#
# [29000 rows x 31 columns]

# %%
df.head(30)
# Out:
#     Unnamed: 0  incident_key               occur_date occur_time       boro  \
# 0            0     209281500  2020-02-08T00:00:00.000   12:13:00     QUEENS
# 1            1     209281497  2020-02-08T00:00:00.000   02:20:00   BROOKLYN
# 2            2     209281498  2020-02-07T00:00:00.000   22:50:00   BROOKLYN
# 3            3     209099251  2020-02-05T00:00:00.000   04:02:00     QUEENS
# 4            4     209098666  2020-02-05T00:00:00.000   23:13:00  MANHATTAN
# 5            5     209099250  2020-02-05T00:00:00.000   11:51:00     QUEENS
# 6            6     209029422  2020-02-04T00:00:00.000   18:43:00   BROOKLYN
# 7            7     209029422  2020-02-04T00:00:00.000   18:43:00   BROOKLYN
# 8            8     208955529  2020-02-03T00:00:00.000   21:12:00      BRONX
# 9            9     208899477  2020-02-02T00:00:00.000   15:55:00   BROOKLYN
# 10          10     208899478  2020-02-02T00:00:00.000   02:32:00  MANHATTAN
# 11          11     208899076  2020-02-01T00:00:00.000   05:09:00      BRONX
# 12          12     208899076  2020-02-01T00:00:00.000   05:09:00      BRONX
# 13          13     208733991  2020-01-29T00:00:00.000   20:30:00   BROOKLYN
# 14          14     208733991  2020-01-29T00:00:00.000   20:30:00   BROOKLYN
# 15          15     208672085  2020-01-28T00:00:00.000   20:16:00     QUEENS
# 16          16     208671535  2020-01-28T00:00:00.000   14:30:00     QUEENS
# 17          17     208600971  2020-01-27T00:00:00.000   21:30:00   BROOKLYN
# 18          18     208549424  2020-01-26T00:00:00.000   17:30:00  MANHATTAN
# 19          19     208549976  2020-01-26T00:00:00.000   23:16:00  MANHATTAN
# 20          20     208532947  2020-01-26T00:00:00.000   00:27:00      BRONX
# 21          21     208531436  2020-01-25T00:00:00.000   03:39:00      BRONX
# 22          22     208549977  2020-01-25T00:00:00.000   04:58:00   BROOKLYN
# 23          23     208532946  2020-01-25T00:00:00.000   20:05:00     QUEENS
# 24          24     208532945  2020-01-25T00:00:00.000   10:30:00      BRONX
# 25          25     208531435  2020-01-25T00:00:00.000   01:30:00  MANHATTAN
# 26          26     208530038  2020-01-24T00:00:00.000   14:48:00   BROOKLYN
# 27          27     208437742  2020-01-23T00:00:00.000   14:00:00  MANHATTAN
# 28          28     208437742  2020-01-23T00:00:00.000   14:00:00  MANHATTAN
# 29          29     208437742  2020-01-23T00:00:00.000   14:00:00  MANHATTAN
#
#     precinct  jurisdiction_code  statistical_murder_flag perp_age_group  \
# 0        115                0.0                     True          25-44
# 1         76                0.0                     True          25-44
# 2         75                0.0                    False          25-44
# 3        101                0.0                    False            NaN
# 4         34                0.0                    False          18-24
# 5        101                0.0                    False            NaN
# 6         75                0.0                     True          18-24
# 7         75                0.0                     True          18-24
# 8         47                0.0                     True          45-64
# 9         84                0.0                    False            <18
# 10        25                0.0                    False          25-44
# 11        50                0.0                    False          18-24
# 12        50                0.0                    False          25-44
# 13        75                0.0                    False          25-44
# 14        75                0.0                    False          25-44
# 15       100                0.0                    False            NaN
# 16       105                0.0                    False            NaN
# 17        69                0.0                    False          25-44
# 18        32                2.0                    False          25-44
# 19        32                0.0                    False            NaN
# 20        43                0.0                    False          25-44
# 21        47                0.0                    False          25-44
# 22        73                0.0                     True          25-44
# 23       105                0.0                    False          25-44
# 24        41                2.0                    False            NaN
# 25        28                0.0                    False            NaN
# 26        90                2.0                    False            NaN
# 27        30                0.0                    False          18-24
# 28        30                0.0                     True          18-24
# 29        30                0.0                    False          18-24
#
#    perp_sex  ...               :created_at               :updated_at  \
# 0         M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 1         M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 2         M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 3       NaN  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 4         M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 5       NaN  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:34.986Z
# 6         F  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 7         M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:34.986Z
# 8         M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 9         M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 10        M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 11        F  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 12        M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:34.986Z
# 13        M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:34.986Z
# 14        M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:34.986Z
# 15      NaN  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 16      NaN  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:34.986Z
# 17        M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:34.986Z
# 18        F  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 19      NaN  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 20        M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:34.986Z
# 21        M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 22        M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 23        M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 24      NaN  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:34.986Z
# 25      NaN  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:34.986Z
# 26      NaN  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 27        M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 28        M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
# 29        M  ...  2024-04-23T13:36:19.239Z  2024-04-23T13:36:30.560Z
#
#    :@computed_region_yeji_bk3q :@computed_region_92fq_4b7q  \
# 0                          3.0                        21.0
# 1                          2.0                         7.0
# 2                          2.0                        37.0
# 3                          3.0                        47.0
# 4                          4.0                        39.0
# 5                          3.0                        47.0
# 6                          2.0                        25.0
# 7                          2.0                        25.0
# 8                          5.0                        40.0
# 9                          2.0                        38.0
# 10                         4.0                        36.0
# 11                         5.0                        40.0
# 12                         5.0                        40.0
# 13                         2.0                        37.0
# 14                         2.0                        37.0
# 15                         3.0                        47.0
# 16                         3.0                        16.0
# 17                         2.0                        25.0
# 18                         4.0                        36.0
# 19                         4.0                        36.0
# 20                         5.0                        31.0
# 21                         5.0                         2.0
# 22                         2.0                        17.0
# 23                         3.0                        47.0
# 24                         5.0                        43.0
# 25                         4.0                        36.0
# 26                         2.0                        30.0
# 27                         4.0                        23.0
# 28                         4.0                        23.0
# 29                         4.0                        23.0
#
#    :@computed_region_sbqj_enih :@computed_region_efsh_h5xi  \
# 0                         73.0                     14510.0
# 1                         48.0                     13514.0
# 2                         47.0                     17214.0
# 3                         59.0                     20529.0
# 4                         22.0                     13098.0
# 5                         59.0                     20529.0
# 6                         47.0                     17215.0
# 7                         47.0                     17215.0
# 8                         30.0                     11608.0
# 9                         54.0                     17619.0
# 10                        16.0                     13093.0
# 11                        33.0                     11272.0
# 12                        33.0                     11272.0
# 13                        47.0                     17215.0
# 14                        47.0                     17215.0
# 15                        58.0                     20530.0
# 16                        63.0                     24336.0
# 17                        42.0                     13827.0
# 18                        20.0                     12427.0
# 19                        20.0                     12427.0
# 20                        26.0                     11610.0
# 21                        30.0                     11605.0
# 22                        46.0                     17614.0
# 23                        63.0                     24669.0
# 24                        24.0                     10937.0
# 25                        18.0                     12424.0
# 26                        56.0                     17213.0
# 27                        19.0                     12428.0
# 28                        19.0                     12428.0
# 29                        19.0                     12428.0
#
#     :@computed_region_f5dn_yrer              location_desc loc_of_occur_desc  \
# 0                          65.0                        NaN               NaN
# 1                          14.0                        NaN               NaN
# 2                          45.0                        NaN               NaN
# 3                          51.0    MULTI DWELL - APT BUILD               NaN
# 4                          47.0    MULTI DWELL - APT BUILD               NaN
# 5                          51.0                        NaN               NaN
# 6                          45.0                        NaN               NaN
# 7                          45.0                        NaN               NaN
# 8                          29.0                        NaN               NaN
# 9                          68.0                        NaN               NaN
# 10                          7.0                        NaN               NaN
# 11                         48.0                        NaN               NaN
# 12                         48.0                        NaN               NaN
# 13                         45.0                        NaN               NaN
# 14                         45.0                        NaN               NaN
# 15                         51.0                        NaN               NaN
# 16                         63.0                        NaN               NaN
# 17                          5.0             GROCERY/BODEGA               NaN
# 18                         18.0  MULTI DWELL - PUBLIC HOUS               NaN
# 19                         18.0             GROCERY/BODEGA               NaN
# 20                         58.0             BAR/NIGHT CLUB               NaN
# 21                         29.0                        NaN               NaN
# 22                         55.0    MULTI DWELL - APT BUILD               NaN
# 23                         63.0                        NaN               NaN
# 24                          8.0  MULTI DWELL - PUBLIC HOUS               NaN
# 25                         18.0           RESTAURANT/DINER               NaN
# 26                         36.0  MULTI DWELL - PUBLIC HOUS               NaN
# 27                         37.0                        NaN               NaN
# 28                         37.0                        NaN               NaN
# 29                         37.0                        NaN               NaN
#
#    loc_classfctn_desc
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
#
# [30 rows x 31 columns]

# %%
df.describe()
# Out:
#          Unnamed: 0  incident_key      precinct  jurisdiction_code  \
# count  29000.000000  2.900000e+04  29000.000000       28998.000000
# mean     499.500000  1.369615e+08     65.207207           0.318263
# std      288.679968  8.149749e+07     27.373641           0.729037
# min        0.000000  1.681403e+07      1.000000           0.000000
# 25%      249.750000  7.175669e+07     44.000000           0.000000
# 50%      499.500000  1.373719e+08     67.000000           0.000000
# 75%      749.250000  2.153030e+08     81.000000           0.000000
# max      999.000000  2.994625e+08    123.000000           2.000000
#
#            latitude     longitude  :@computed_region_yeji_bk3q  \
# count  28903.000000  28903.000000                 28903.000000
# mean      40.739519    -73.908989                     3.280525
# std        0.087726      0.065619                     1.320795
# min       40.511586    -74.249303                     1.000000
# 25%       40.669045    -73.942736                     2.000000
# 50%       40.703146    -73.914762                     3.000000
# 75%       40.825389    -73.882660                     5.000000
# max       40.910818    -73.702046                     5.000000
#
#        :@computed_region_92fq_4b7q  :@computed_region_sbqj_enih  \
# count                 28903.000000                 28903.000000
# mean                     29.829845                    40.424489
# std                      13.940465                    16.924575
# min                       1.000000                     1.000000
# 25%                      17.000000                    27.000000
# 50%                      31.000000                    40.000000
# 75%                      42.000000                    52.000000
# max                      51.000000                    77.000000
#
#        :@computed_region_efsh_h5xi  :@computed_region_f5dn_yrer
# count                 28862.000000                 28903.000000
# mean                  14713.522625                    38.665433
# std                    3784.021785                    20.280171
# min                   10090.000000                     1.000000
# 25%                   11605.000000                    18.000000
# 50%                   13512.000000                    42.000000
# 75%                   17215.000000                    55.000000
# max                   24894.000000                    71.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 29000 entries, 0 to 28999
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   29000 non-null  int64
#  1   incident_key                 29000 non-null  int64
#  2   occur_date                   29000 non-null  str
#  3   occur_time                   29000 non-null  str
#  4   boro                         29000 non-null  str
#  5   precinct                     29000 non-null  int64
#  6   jurisdiction_code            28998 non-null  float64
#  7   statistical_murder_flag      29000 non-null  bool
#  8   perp_age_group               19703 non-null  str
#  9   perp_sex                     19704 non-null  str
#  10  perp_race                    19704 non-null  str
#  11  vic_age_group                29000 non-null  str
#  12  vic_sex                      29000 non-null  str
#  13  vic_race                     29000 non-null  str
#  14  x_coord_cd                   29000 non-null  str
#  15  y_coord_cd                   29000 non-null  str
#  16  latitude                     28903 non-null  float64
#  17  longitude                    28903 non-null  float64
#  18  geocoded_column              28903 non-null  str
#  19  :id                          29000 non-null  str
#  20  :version                     29000 non-null  str
#  21  :created_at                  29000 non-null  str
#  22  :updated_at                  29000 non-null  str
#  23  :@computed_region_yeji_bk3q  28903 non-null  float64
#  24  :@computed_region_92fq_4b7q  28903 non-null  float64
#  25  :@computed_region_sbqj_enih  28903 non-null  float64
#  26  :@computed_region_efsh_h5xi  28862 non-null  float64
#  27  :@computed_region_f5dn_yrer  28903 non-null  float64
#  28  location_desc                14306 non-null  str
#  29  loc_of_occur_desc            4148 non-null   str
#  30  loc_classfctn_desc           4148 non-null   str
# dtypes: bool(1), float64(8), int64(3), str(19)
# memory usage: 6.7 MB

# %% [markdown]
# #Perpetrator and Victim Gender Split

# %%
# Perpetrator Gender
df['perp_sex'].value_counts().plot.bar()

plt.title('Perpetrator Gender')
plt.xlabel('Gender')
plt.xticks(rotation=90)
plt.ylabel('Count of Perps')
plt.show()

# %%
# Victim Gender
df['vic_sex'].value_counts().plot.bar()

plt.title('Victim Gender')
plt.xlabel('Gender')
plt.xticks(rotation=90)
plt.ylabel('Count of Victims')
plt.show()

# %% [markdown]
# #Pereptrator Sex by Age Analysis

# %%
# Perpetrator sex and age information 

pivot_sex_by_age = df.pivot_table(values= 'Unnamed: 0', index = 'perp_age_group', columns='perp_sex', aggfunc='size')
print(pivot_sex_by_age)
# Out:
# perp_sex        (null)      F       M       U
# perp_age_group
# (null)          1628.0    NaN     NaN     NaN
# 1020               NaN    NaN     1.0     NaN
# 1028               NaN    NaN     1.0     NaN
# 18-24              NaN  165.0  6271.0    17.0
# 2021               NaN    NaN     1.0     NaN
# 224                NaN    NaN     1.0     NaN
# 25-44              NaN  203.0  5959.0     7.0
# 45-64              NaN   28.0   735.0     NaN
# 65+                NaN    2.0    64.0     NaN
# 940                NaN    NaN     1.0     NaN
# <18                NaN   38.0  1709.0     3.0
# UNKNOWN            NaN   17.0  1531.0  1321.0

# %%
#Filters out invalid age values
valid_ages = ['<18', '18-24', '25-44', '45-64', '65+']
valid_sex = ['M', 'F']

pivot_sex_by_age = pivot_sex_by_age[
    pivot_sex_by_age.index.isin(valid_ages)
].reindex(columns=valid_sex, fill_value=0)

print(pivot_sex_by_age)

pivot_sex_by_age.plot.bar(stacked=True)
plt.title('Perpetrator age by Gender')
plt.xlabel('Age Group')
plt.xticks(rotation=90)
plt.ylabel('Count of Perps')
plt.show()
# Out:
# perp_sex             M      F
# perp_age_group
# 18-24           6271.0  165.0
# 25-44           5959.0  203.0
# 45-64            735.0   28.0
# 65+               64.0    2.0
# <18             1709.0   38.0

# %% [markdown]
# #Victim and Perpetrator Sex by Location/Borough Analysis

# %%
# Victim sex and location info
pivot_vic_sex_by_location = df.pivot_table(values= 'Unnamed: 0', index = 'location_desc', columns='vic_sex', aggfunc='size')
print(pivot_vic_sex_by_location)

valid_sex = ['F', 'M']
pivot_vic_sex_by_location = pivot_vic_sex_by_location.reindex(columns=valid_sex, fill_value=0)

pivot_vic_sex_by_location.plot.bar(
    stacked=True,
    figsize=(12,6)
    )
plt.title('Victim Location by Gender')
plt.xlabel('Location')
plt.xticks(rotation=90)
plt.ylabel('Count of Victims')
plt.show()
# Out:
# vic_sex                        F       M    U
# location_desc
# (null)                     258.0  2267.0  1.0
# ATM                          NaN     1.0  NaN
# BANK                         NaN     3.0  NaN
# BAR/NIGHT CLUB              91.0   573.0  NaN
# BEAUTY/NAIL SALON           15.0   103.0  NaN
# CANDY STORE                  1.0     9.0  NaN
# CHAIN STORE                  NaN     8.0  NaN
# CHECK CASH                   NaN     1.0  NaN
# CLOTHING BOUTIQUE            NaN    10.0  NaN
# COMMERCIAL BLDG             32.0   268.0  NaN
# DEPT STORE                   1.0     8.0  NaN
# DOCTOR/DENTIST               NaN     1.0  NaN
# DRUG STORE                   1.0    13.0  NaN
# DRY CLEANER/LAUNDRY          3.0    25.0  NaN
# FACTORY/WAREHOUSE            NaN     6.0  NaN
# FAST FOOD                    5.0   120.0  NaN
# GAS STATION                  2.0    73.0  NaN
# GROCERY/BODEGA              52.0   707.0  NaN
# GYM/FITNESS FACILITY         1.0     3.0  NaN
# HOSPITAL                     7.0    77.0  NaN
# HOTEL/MOTEL                  7.0    30.0  NaN
# JEWELRY STORE                NaN    11.0  NaN
# LIQUOR STORE                 2.0    40.0  NaN
# LOAN COMPANY                 NaN     1.0  NaN
# MULTI DWELL - APT BUILD    442.0  2534.0  1.0
# MULTI DWELL - PUBLIC HOUS  500.0  4575.0  2.0
# NONE                         NaN     8.0  NaN
# PHOTO/COPY STORE             NaN     2.0  NaN
# PVT HOUSE                  179.0   807.0  NaN
# RESTAURANT/DINER            19.0   187.0  NaN
# SHOE STORE                   NaN    10.0  NaN
# SMALL MERCHANT               4.0    42.0  NaN
# SOCIAL CLUB/POLICY LOCATI    8.0    66.0  NaN
# STORAGE FACILITY             NaN     1.0  NaN
# STORE UNCLASSIFIED           2.0    31.0  NaN
# SUPERMARKET                  3.0    17.0  NaN
# TELECOMM. STORE              2.0     9.0  NaN
# VARIETY STORE                NaN    10.0  NaN
# VIDEO STORE                  NaN     8.0  NaN

# %%
# Perpetrator sex and location info
pivot_perp_sex_by_location = df.pivot_table(values= 'Unnamed: 0', index = 'location_desc', columns='perp_sex', aggfunc='size')
print(pivot_perp_sex_by_location)


valid_sex = ['F', 'M']
pivot_perp_sex_by_location = pivot_perp_sex_by_location.reindex(columns=valid_sex, fill_value=0)

pivot_perp_sex_by_location.plot.bar(
    stacked=True,
    figsize=(12,6)
)

plt.title('Perpetrator Location by Gender')
plt.xlabel('Location')
plt.xticks(rotation=90)
plt.ylabel('Count of Perps')
plt.show()
# Out:
# perp_sex                   (null)     F       M      U
# location_desc
# (null)                      995.0  56.0  1474.0    1.0
# BANK                          NaN   1.0     1.0    NaN
# BAR/NIGHT CLUB               54.0   4.0   419.0   52.0
# BEAUTY/NAIL SALON             5.0   1.0    79.0    5.0
# CANDY STORE                   1.0   NaN     6.0    NaN
# CHAIN STORE                   2.0   NaN     5.0    NaN
# CHECK CASH                    NaN   NaN     1.0    NaN
# CLOTHING BOUTIQUE             NaN   NaN     4.0    1.0
# COMMERCIAL BLDG              17.0   3.0   161.0   19.0
# DEPT STORE                    NaN   1.0     8.0    NaN
# DOCTOR/DENTIST                NaN   NaN     1.0    NaN
# DRUG STORE                    NaN   NaN    13.0    NaN
# DRY CLEANER/LAUNDRY           1.0   NaN    15.0    1.0
# FACTORY/WAREHOUSE             NaN   NaN     5.0    NaN
# FAST FOOD                     3.0   1.0    80.0    4.0
# GAS STATION                   3.0   1.0    45.0    4.0
# GROCERY/BODEGA               37.0  11.0   503.0   34.0
# GYM/FITNESS FACILITY          NaN   NaN     3.0    NaN
# HOSPITAL                     30.0   NaN    25.0    1.0
# HOTEL/MOTEL                   NaN   3.0    32.0    NaN
# JEWELRY STORE                 1.0   NaN    10.0    NaN
# LIQUOR STORE                  NaN   1.0    32.0    NaN
# LOAN COMPANY                  NaN   NaN     1.0    NaN
# MULTI DWELL - APT BUILD     120.0  91.0  2000.0  123.0
# MULTI DWELL - PUBLIC HOUS   297.0  72.0  2708.0  250.0
# NONE                          NaN   NaN     6.0    2.0
# PHOTO/COPY STORE              1.0   NaN     1.0    NaN
# PVT HOUSE                    40.0  30.0   594.0   31.0
# RESTAURANT/DINER              6.0   NaN   138.0   10.0
# SHOE STORE                    NaN   NaN     9.0    NaN
# SMALL MERCHANT                9.0   2.0    31.0    1.0
# SOCIAL CLUB/POLICY LOCATI     6.0   NaN    38.0    4.0
# STORAGE FACILITY              NaN   NaN     1.0    NaN
# STORE UNCLASSIFIED            NaN   1.0    24.0    2.0
# SUPERMARKET                   NaN   NaN    17.0    1.0
# TELECOMM. STORE               NaN   NaN    11.0    NaN
# VARIETY STORE                 NaN   NaN     7.0    NaN
# VIDEO STORE                   NaN   NaN     7.0    NaN

# %%
pivot_vic_sex_by_boro = df.pivot_table(values= 'Unnamed: 0', index = 'boro', columns='vic_sex', aggfunc='size')
print(pivot_vic_sex_by_boro)

pivot_vic_sex_by_boro = pivot_vic_sex_by_boro.reindex(columns=valid_sex, fill_value=0)

pivot_vic_sex_by_boro.plot.bar(stacked=True)

plt.title('Victim Gender by Borough')
plt.xlabel('Borough')
plt.xticks(rotation=90)
plt.ylabel('Count of Victims')
plt.show()
# Out:
# vic_sex             F        M    U
# boro
# BRONX           777.0   7850.0  3.0
# BROOKLYN       1120.0  10253.0  6.0
# MANHATTAN       389.0   3481.0  3.0
# QUEENS          457.0   3861.0  NaN
# STATEN ISLAND    97.0    703.0  NaN

# %%
pivot_perp_sex_by_boro = df.pivot_table(values= 'Unnamed: 0', index = 'boro', columns='perp_sex', aggfunc='size')
print(pivot_perp_sex_by_boro)


pivot_perp_sex_by_boro = pivot_perp_sex_by_boro.reindex(columns=valid_sex, fill_value=0)

pivot_perp_sex_by_boro.plot.bar(stacked=True)

plt.title('Perpetrator Gender by Borough')
plt.xlabel('Borough')
plt.xticks(rotation=90)
plt.ylabel('Count of Perps')
plt.show()
# Out:
# perp_sex       (null)    F     M    U
# boro
# BRONX             518  131  5118  364
# BROOKLYN          635  143  5738  584
# MANHATTAN         191   87  2408  167
# QUEENS            257   78  2417  210
# STATEN ISLAND      27   14   593   24
